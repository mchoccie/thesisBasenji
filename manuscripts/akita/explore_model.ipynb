# %%
import os
import json
import subprocess
import sys
sys.path.insert(0, '/home/017448899/basenji_thesis/basenji')
os.environ["CUDA_VISIBLE_DEVICES"] = '-1' ### run on CPU
import dataset, dna_io, seqnn
from cooltools.lib.numutils import set_diag
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pysam
import tensorflow as tf

# %%
print(seqnn.__file__)
# Out:
# /home/017448899/basenji_thesis/basenji/seqnn.py

# %% [markdown]
# ## Load trained model

# %%
### load params, specify model ###

model_dir = '/home/017448899/basenji_thesis/manuscripts/akita/data/1m/train_out/'
params_file = model_dir+'params.json'
model_file  = model_dir+'model_best.h5'
with open(params_file) as params_open:
    params = json.load(params_open)
    params_model = params['model']
    params_train = params['train']

seqnn_model = seqnn.SeqNN(params_model)
# Out:
# This is cropping32
# This is inputs shapeeeeeeeeeeeeeeeeeeeeeeee (None, 512, 512, 48)
# This is triu_tup (array([  0,   0,   0, ..., 444, 444, 445]), array([  2,   3,   4, ..., 446, 447, 447]))
# Model: "model_19"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  sequence (InputLayer)       [(None, 1048576, 4)]         0         []
#
#  stochastic_reverse_complem  ((None, 1048576, 4),         0         ['sequence[0][0]']
#  ent_9 (StochasticReverseCo   ())
#  mplement)
#
#  stochastic_shift_9 (Stocha  (None, 1048576, 4)           0         ['stochastic_reverse_complemen
#  sticShift)                                                         t_9[0][0]']
#
#  re_lu_376 (ReLU)            (None, 1048576, 4)           0         ['stochastic_shift_9[0][0]']
#
#  conv1d_236 (Conv1D)         (None, 1048576, 96)          4224      ['re_lu_376[0][0]']
#
#  batch_normalization_351 (B  (None, 1048576, 96)          384       ['conv1d_236[0][0]']
#  atchNormalization)
#
#  max_pooling1d_99 (MaxPooli  (None, 524288, 96)           0         ['batch_normalization_351[0][0
#  ng1D)                                                              ]']
#
#  re_lu_377 (ReLU)            (None, 524288, 96)           0         ['max_pooling1d_99[0][0]']
#
#  conv1d_237 (Conv1D)         (None, 524288, 96)           46080     ['re_lu_377[0][0]']
#
#  batch_normalization_352 (B  (None, 524288, 96)           384       ['conv1d_237[0][0]']
#  atchNormalization)
#
#  max_pooling1d_100 (MaxPool  (None, 262144, 96)           0         ['batch_normalization_352[0][0
#  ing1D)                                                             ]']
#
#  re_lu_378 (ReLU)            (None, 262144, 96)           0         ['max_pooling1d_100[0][0]']
#
#  conv1d_238 (Conv1D)         (None, 262144, 96)           46080     ['re_lu_378[0][0]']
#
#  batch_normalization_353 (B  (None, 262144, 96)           384       ['conv1d_238[0][0]']
#  atchNormalization)
#
#  max_pooling1d_101 (MaxPool  (None, 131072, 96)           0         ['batch_normalization_353[0][0
#  ing1D)                                                             ]']
#
#  re_lu_379 (ReLU)            (None, 131072, 96)           0         ['max_pooling1d_101[0][0]']
#
#  conv1d_239 (Conv1D)         (None, 131072, 96)           46080     ['re_lu_379[0][0]']
#
#  batch_normalization_354 (B  (None, 131072, 96)           384       ['conv1d_239[0][0]']
#  atchNormalization)
#
#  max_pooling1d_102 (MaxPool  (None, 65536, 96)            0         ['batch_normalization_354[0][0
#  ing1D)                                                             ]']
#
#  re_lu_380 (ReLU)            (None, 65536, 96)            0         ['max_pooling1d_102[0][0]']
#
#  conv1d_240 (Conv1D)         (None, 65536, 96)            46080     ['re_lu_380[0][0]']
#
#  batch_normalization_355 (B  (None, 65536, 96)            384       ['conv1d_240[0][0]']
#  atchNormalization)
#
#  max_pooling1d_103 (MaxPool  (None, 32768, 96)            0         ['batch_normalization_355[0][0
#  ing1D)                                                             ]']
#
#  re_lu_381 (ReLU)            (None, 32768, 96)            0         ['max_pooling1d_103[0][0]']
#
#  conv1d_241 (Conv1D)         (None, 32768, 96)            46080     ['re_lu_381[0][0]']
#
#  batch_normalization_356 (B  (None, 32768, 96)            384       ['conv1d_241[0][0]']
#  atchNormalization)
#
#  max_pooling1d_104 (MaxPool  (None, 16384, 96)            0         ['batch_normalization_356[0][0
#  ing1D)                                                             ]']
#
#  re_lu_382 (ReLU)            (None, 16384, 96)            0         ['max_pooling1d_104[0][0]']
#
#  conv1d_242 (Conv1D)         (None, 16384, 96)            46080     ['re_lu_382[0][0]']
#
#  batch_normalization_357 (B  (None, 16384, 96)            384       ['conv1d_242[0][0]']
#  atchNormalization)
#
#  max_pooling1d_105 (MaxPool  (None, 8192, 96)             0         ['batch_normalization_357[0][0
#  ing1D)                                                             ]']
#
#  re_lu_383 (ReLU)            (None, 8192, 96)             0         ['max_pooling1d_105[0][0]']
#
#  conv1d_243 (Conv1D)         (None, 8192, 96)             46080     ['re_lu_383[0][0]']
#
#  batch_normalization_358 (B  (None, 8192, 96)             384       ['conv1d_243[0][0]']
#  atchNormalization)
#
#  max_pooling1d_106 (MaxPool  (None, 4096, 96)             0         ['batch_normalization_358[0][0
#  ing1D)                                                             ]']
#
#  re_lu_384 (ReLU)            (None, 4096, 96)             0         ['max_pooling1d_106[0][0]']
#
#  conv1d_244 (Conv1D)         (None, 4096, 96)             46080     ['re_lu_384[0][0]']
#
#  batch_normalization_359 (B  (None, 4096, 96)             384       ['conv1d_244[0][0]']
#  atchNormalization)
#
#  max_pooling1d_107 (MaxPool  (None, 2048, 96)             0         ['batch_normalization_359[0][0
#  ing1D)                                                             ]']
#
#  re_lu_385 (ReLU)            (None, 2048, 96)             0         ['max_pooling1d_107[0][0]']
#
#  conv1d_245 (Conv1D)         (None, 2048, 96)             46080     ['re_lu_385[0][0]']
#
#  batch_normalization_360 (B  (None, 2048, 96)             384       ['conv1d_245[0][0]']
#  atchNormalization)
#
#  max_pooling1d_108 (MaxPool  (None, 1024, 96)             0         ['batch_normalization_360[0][0
#  ing1D)                                                             ]']
#
#  re_lu_386 (ReLU)            (None, 1024, 96)             0         ['max_pooling1d_108[0][0]']
#
#  conv1d_246 (Conv1D)         (None, 1024, 96)             46080     ['re_lu_386[0][0]']
#
#  batch_normalization_361 (B  (None, 1024, 96)             384       ['conv1d_246[0][0]']
#  atchNormalization)
#
#  max_pooling1d_109 (MaxPool  (None, 512, 96)              0         ['batch_normalization_361[0][0
#  ing1D)                                                             ]']
#
#  re_lu_387 (ReLU)            (None, 512, 96)              0         ['max_pooling1d_109[0][0]']
#
#  conv1d_247 (Conv1D)         (None, 512, 48)              13824     ['re_lu_387[0][0]']
#
#  batch_normalization_362 (B  (None, 512, 48)              192       ['conv1d_247[0][0]']
#  atchNormalization)
#
#  re_lu_388 (ReLU)            (None, 512, 48)              0         ['batch_normalization_362[0][0
#                                                                     ]']
#
#  conv1d_248 (Conv1D)         (None, 512, 96)              4608      ['re_lu_388[0][0]']
#
#  batch_normalization_363 (B  (None, 512, 96)              384       ['conv1d_248[0][0]']
#  atchNormalization)
#
#  dropout_162 (Dropout)       (None, 512, 96)              0         ['batch_normalization_363[0][0
#                                                                     ]']
#
#  add_156 (Add)               (None, 512, 96)              0         ['max_pooling1d_109[0][0]',
#                                                                      'dropout_162[0][0]']
#
#  re_lu_389 (ReLU)            (None, 512, 96)              0         ['add_156[0][0]']
#
#  conv1d_249 (Conv1D)         (None, 512, 48)              13824     ['re_lu_389[0][0]']
#
#  batch_normalization_364 (B  (None, 512, 48)              192       ['conv1d_249[0][0]']
#  atchNormalization)
#
#  re_lu_390 (ReLU)            (None, 512, 48)              0         ['batch_normalization_364[0][0
#                                                                     ]']
#
#  conv1d_250 (Conv1D)         (None, 512, 96)              4608      ['re_lu_390[0][0]']
#
#  batch_normalization_365 (B  (None, 512, 96)              384       ['conv1d_250[0][0]']
#  atchNormalization)
#
#  dropout_163 (Dropout)       (None, 512, 96)              0         ['batch_normalization_365[0][0
#                                                                     ]']
#
#  add_157 (Add)               (None, 512, 96)              0         ['add_156[0][0]',
#                                                                      'dropout_163[0][0]']
#
#  re_lu_391 (ReLU)            (None, 512, 96)              0         ['add_157[0][0]']
#
#  conv1d_251 (Conv1D)         (None, 512, 48)              13824     ['re_lu_391[0][0]']
#
#  batch_normalization_366 (B  (None, 512, 48)              192       ['conv1d_251[0][0]']
#  atchNormalization)
#
#  re_lu_392 (ReLU)            (None, 512, 48)              0         ['batch_normalization_366[0][0
#                                                                     ]']
#
#  conv1d_252 (Conv1D)         (None, 512, 96)              4608      ['re_lu_392[0][0]']
#
#  batch_normalization_367 (B  (None, 512, 96)              384       ['conv1d_252[0][0]']
#  atchNormalization)
#
#  dropout_164 (Dropout)       (None, 512, 96)              0         ['batch_normalization_367[0][0
#                                                                     ]']
#
#  add_158 (Add)               (None, 512, 96)              0         ['add_157[0][0]',
#                                                                      'dropout_164[0][0]']
#
#  re_lu_393 (ReLU)            (None, 512, 96)              0         ['add_158[0][0]']
#
#  conv1d_253 (Conv1D)         (None, 512, 48)              13824     ['re_lu_393[0][0]']
#
#  batch_normalization_368 (B  (None, 512, 48)              192       ['conv1d_253[0][0]']
#  atchNormalization)
#
#  re_lu_394 (ReLU)            (None, 512, 48)              0         ['batch_normalization_368[0][0
#                                                                     ]']
#
#  conv1d_254 (Conv1D)         (None, 512, 96)              4608      ['re_lu_394[0][0]']
#
#  batch_normalization_369 (B  (None, 512, 96)              384       ['conv1d_254[0][0]']
#  atchNormalization)
#
#  dropout_165 (Dropout)       (None, 512, 96)              0         ['batch_normalization_369[0][0
#                                                                     ]']
#
#  add_159 (Add)               (None, 512, 96)              0         ['add_158[0][0]',
#                                                                      'dropout_165[0][0]']
#
#  re_lu_395 (ReLU)            (None, 512, 96)              0         ['add_159[0][0]']
#
#  conv1d_255 (Conv1D)         (None, 512, 48)              13824     ['re_lu_395[0][0]']
#
#  batch_normalization_370 (B  (None, 512, 48)              192       ['conv1d_255[0][0]']
#  atchNormalization)
#
#  re_lu_396 (ReLU)            (None, 512, 48)              0         ['batch_normalization_370[0][0
#                                                                     ]']
#
#  conv1d_256 (Conv1D)         (None, 512, 96)              4608      ['re_lu_396[0][0]']
#
#  batch_normalization_371 (B  (None, 512, 96)              384       ['conv1d_256[0][0]']
#  atchNormalization)
#
#  dropout_166 (Dropout)       (None, 512, 96)              0         ['batch_normalization_371[0][0
#                                                                     ]']
#
#  add_160 (Add)               (None, 512, 96)              0         ['add_159[0][0]',
#                                                                      'dropout_166[0][0]']
#
#  re_lu_397 (ReLU)            (None, 512, 96)              0         ['add_160[0][0]']
#
#  conv1d_257 (Conv1D)         (None, 512, 48)              13824     ['re_lu_397[0][0]']
#
#  batch_normalization_372 (B  (None, 512, 48)              192       ['conv1d_257[0][0]']
#  atchNormalization)
#
#  re_lu_398 (ReLU)            (None, 512, 48)              0         ['batch_normalization_372[0][0
#                                                                     ]']
#
#  conv1d_258 (Conv1D)         (None, 512, 96)              4608      ['re_lu_398[0][0]']
#
#  batch_normalization_373 (B  (None, 512, 96)              384       ['conv1d_258[0][0]']
#  atchNormalization)
#
#  dropout_167 (Dropout)       (None, 512, 96)              0         ['batch_normalization_373[0][0
#                                                                     ]']
#
#  add_161 (Add)               (None, 512, 96)              0         ['add_160[0][0]',
#                                                                      'dropout_167[0][0]']
#
#  re_lu_399 (ReLU)            (None, 512, 96)              0         ['add_161[0][0]']
#
#  conv1d_259 (Conv1D)         (None, 512, 48)              13824     ['re_lu_399[0][0]']
#
#  batch_normalization_374 (B  (None, 512, 48)              192       ['conv1d_259[0][0]']
#  atchNormalization)
#
#  re_lu_400 (ReLU)            (None, 512, 48)              0         ['batch_normalization_374[0][0
#                                                                     ]']
#
#  conv1d_260 (Conv1D)         (None, 512, 96)              4608      ['re_lu_400[0][0]']
#
#  batch_normalization_375 (B  (None, 512, 96)              384       ['conv1d_260[0][0]']
#  atchNormalization)
#
#  dropout_168 (Dropout)       (None, 512, 96)              0         ['batch_normalization_375[0][0
#                                                                     ]']
#
#  add_162 (Add)               (None, 512, 96)              0         ['add_161[0][0]',
#                                                                      'dropout_168[0][0]']
#
#  re_lu_401 (ReLU)            (None, 512, 96)              0         ['add_162[0][0]']
#
#  conv1d_261 (Conv1D)         (None, 512, 48)              13824     ['re_lu_401[0][0]']
#
#  batch_normalization_376 (B  (None, 512, 48)              192       ['conv1d_261[0][0]']
#  atchNormalization)
#
#  re_lu_402 (ReLU)            (None, 512, 48)              0         ['batch_normalization_376[0][0
#                                                                     ]']
#
#  conv1d_262 (Conv1D)         (None, 512, 96)              4608      ['re_lu_402[0][0]']
#
#  batch_normalization_377 (B  (None, 512, 96)              384       ['conv1d_262[0][0]']
#  atchNormalization)
#
#  dropout_169 (Dropout)       (None, 512, 96)              0         ['batch_normalization_377[0][0
#                                                                     ]']
#
#  add_163 (Add)               (None, 512, 96)              0         ['add_162[0][0]',
#                                                                      'dropout_169[0][0]']
#
#  re_lu_403 (ReLU)            (None, 512, 96)              0         ['add_163[0][0]']
#
#  conv1d_263 (Conv1D)         (None, 512, 64)              30720     ['re_lu_403[0][0]']
#
#  batch_normalization_378 (B  (None, 512, 64)              256       ['conv1d_263[0][0]']
#  atchNormalization)
#
#  re_lu_404 (ReLU)            (None, 512, 64)              0         ['batch_normalization_378[0][0
#                                                                     ]']
#
#  one_to_two_9 (OneToTwo)     (None, 512, 512, 64)         0         ['re_lu_404[0][0]']
#
#  concat_dist2d_9 (ConcatDis  (None, 512, 512, 65)         0         ['one_to_two_9[0][0]']
#  t2D)
#
#  re_lu_405 (ReLU)            (None, 512, 512, 65)         0         ['concat_dist2d_9[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 512, 512, 48)         28080     ['re_lu_405[0][0]']
#
#  batch_normalization_379 (B  (None, 512, 512, 48)         192       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  symmetrize2d_63 (Symmetriz  (None, 512, 512, 48)         0         ['batch_normalization_379[0][0
#  e2D)                                                               ]']
#
#  re_lu_406 (ReLU)            (None, 512, 512, 48)         0         ['symmetrize2d_63[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 512, 512, 24)         10368     ['re_lu_406[0][0]']
#
#  batch_normalization_380 (B  (None, 512, 512, 24)         96        ['conv2d_118[0][0]']
#  atchNormalization)
#
#  re_lu_407 (ReLU)            (None, 512, 512, 24)         0         ['batch_normalization_380[0][0
#                                                                     ]']
#
#  conv2d_119 (Conv2D)         (None, 512, 512, 48)         1152      ['re_lu_407[0][0]']
#
#  batch_normalization_381 (B  (None, 512, 512, 48)         192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  dropout_170 (Dropout)       (None, 512, 512, 48)         0         ['batch_normalization_381[0][0
#                                                                     ]']
#
#  add_164 (Add)               (None, 512, 512, 48)         0         ['symmetrize2d_63[0][0]',
#                                                                      'dropout_170[0][0]']
#
#  symmetrize2d_64 (Symmetriz  (None, 512, 512, 48)         0         ['add_164[0][0]']
#  e2D)
#
#  re_lu_408 (ReLU)            (None, 512, 512, 48)         0         ['symmetrize2d_64[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 512, 512, 24)         10368     ['re_lu_408[0][0]']
#
#  batch_normalization_382 (B  (None, 512, 512, 24)         96        ['conv2d_120[0][0]']
#  atchNormalization)
#
#  re_lu_409 (ReLU)            (None, 512, 512, 24)         0         ['batch_normalization_382[0][0
#                                                                     ]']
#
#  conv2d_121 (Conv2D)         (None, 512, 512, 48)         1152      ['re_lu_409[0][0]']
#
#  batch_normalization_383 (B  (None, 512, 512, 48)         192       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  dropout_171 (Dropout)       (None, 512, 512, 48)         0         ['batch_normalization_383[0][0
#                                                                     ]']
#
#  add_165 (Add)               (None, 512, 512, 48)         0         ['symmetrize2d_64[0][0]',
#                                                                      'dropout_171[0][0]']
#
#  symmetrize2d_65 (Symmetriz  (None, 512, 512, 48)         0         ['add_165[0][0]']
#  e2D)
#
#  re_lu_410 (ReLU)            (None, 512, 512, 48)         0         ['symmetrize2d_65[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 512, 512, 24)         10368     ['re_lu_410[0][0]']
#
#  batch_normalization_384 (B  (None, 512, 512, 24)         96        ['conv2d_122[0][0]']
#  atchNormalization)
#
#  re_lu_411 (ReLU)            (None, 512, 512, 24)         0         ['batch_normalization_384[0][0
#                                                                     ]']
#
#  conv2d_123 (Conv2D)         (None, 512, 512, 48)         1152      ['re_lu_411[0][0]']
#
#  batch_normalization_385 (B  (None, 512, 512, 48)         192       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  dropout_172 (Dropout)       (None, 512, 512, 48)         0         ['batch_normalization_385[0][0
#                                                                     ]']
#
#  add_166 (Add)               (None, 512, 512, 48)         0         ['symmetrize2d_65[0][0]',
#                                                                      'dropout_172[0][0]']
#
#  symmetrize2d_66 (Symmetriz  (None, 512, 512, 48)         0         ['add_166[0][0]']
#  e2D)
#
#  re_lu_412 (ReLU)            (None, 512, 512, 48)         0         ['symmetrize2d_66[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 512, 512, 24)         10368     ['re_lu_412[0][0]']
#
#  batch_normalization_386 (B  (None, 512, 512, 24)         96        ['conv2d_124[0][0]']
#  atchNormalization)
#
#  re_lu_413 (ReLU)            (None, 512, 512, 24)         0         ['batch_normalization_386[0][0
#                                                                     ]']
#
#  conv2d_125 (Conv2D)         (None, 512, 512, 48)         1152      ['re_lu_413[0][0]']
#
#  batch_normalization_387 (B  (None, 512, 512, 48)         192       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  dropout_173 (Dropout)       (None, 512, 512, 48)         0         ['batch_normalization_387[0][0
#                                                                     ]']
#
#  add_167 (Add)               (None, 512, 512, 48)         0         ['symmetrize2d_66[0][0]',
#                                                                      'dropout_173[0][0]']
#
#  symmetrize2d_67 (Symmetriz  (None, 512, 512, 48)         0         ['add_167[0][0]']
#  e2D)
#
#  re_lu_414 (ReLU)            (None, 512, 512, 48)         0         ['symmetrize2d_67[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 512, 512, 24)         10368     ['re_lu_414[0][0]']
#
#  batch_normalization_388 (B  (None, 512, 512, 24)         96        ['conv2d_126[0][0]']
#  atchNormalization)
#
#  re_lu_415 (ReLU)            (None, 512, 512, 24)         0         ['batch_normalization_388[0][0
#                                                                     ]']
#
#  conv2d_127 (Conv2D)         (None, 512, 512, 48)         1152      ['re_lu_415[0][0]']
#
#  batch_normalization_389 (B  (None, 512, 512, 48)         192       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  dropout_174 (Dropout)       (None, 512, 512, 48)         0         ['batch_normalization_389[0][0
#                                                                     ]']
#
#  add_168 (Add)               (None, 512, 512, 48)         0         ['symmetrize2d_67[0][0]',
#                                                                      'dropout_174[0][0]']
#
#  symmetrize2d_68 (Symmetriz  (None, 512, 512, 48)         0         ['add_168[0][0]']
#  e2D)
#
#  re_lu_416 (ReLU)            (None, 512, 512, 48)         0         ['symmetrize2d_68[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 512, 512, 24)         10368     ['re_lu_416[0][0]']
#
#  batch_normalization_390 (B  (None, 512, 512, 24)         96        ['conv2d_128[0][0]']
#  atchNormalization)
#
#  re_lu_417 (ReLU)            (None, 512, 512, 24)         0         ['batch_normalization_390[0][0
#                                                                     ]']
#
#  conv2d_129 (Conv2D)         (None, 512, 512, 48)         1152      ['re_lu_417[0][0]']
#
#  batch_normalization_391 (B  (None, 512, 512, 48)         192       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  dropout_175 (Dropout)       (None, 512, 512, 48)         0         ['batch_normalization_391[0][0
#                                                                     ]']
#
#  add_169 (Add)               (None, 512, 512, 48)         0         ['symmetrize2d_68[0][0]',
#                                                                      'dropout_175[0][0]']
#
#  symmetrize2d_69 (Symmetriz  (None, 512, 512, 48)         0         ['add_169[0][0]']
#  e2D)
#
#  cropping2d_9 (Cropping2D)   (None, 448, 448, 48)         0         ['symmetrize2d_69[0][0]']
#
#  upper_tri_9 (UpperTri)      (None, 99681, 48)            0         ['cropping2d_9[0][0]']
#
#  dense_41 (Dense)            (None, 99681, 2)             98        ['upper_tri_9[0][0]']
#
#  switch_reverse_triu_9 (Swi  (None, 99681, 2)             0         ['dense_41[0][0]',
#  tchReverseTriu)                                                     'stochastic_reverse_complemen
#                                                                     t_9[0][1]']
#
# ==================================================================================================
# Total params: 751506 (2.87 MB)
# Trainable params: 746002 (2.85 MB)
# Non-trainable params: 5504 (21.50 KB)
# __________________________________________________________________________________________________
# None
# model_strides [2048]
# target_lengths [99681]
# target_crops [-49585]

# %%
### restore model ###
# note: run %%bash get_model.sh 
# if you have not already downloaded the model
seqnn_model.restore(model_file)
print('successfully loaded')
# Out:
# successfully loaded

# %%
### names of targets ###
data_dir =   './data/'

hic_targets = pd.read_csv(data_dir+'/targets.txt',sep='\t')
hic_file_dict_num = dict(zip(hic_targets['index'].values, hic_targets['file'].values) )
hic_file_dict     = dict(zip(hic_targets['identifier'].values, hic_targets['file'].values) )
hic_num_to_name_dict = dict(zip(hic_targets['index'].values, hic_targets['identifier'].values) )

# read data parameters
data_stats_file = '%s/statistics.json' % data_dir
with open(data_stats_file) as data_stats_open:
    data_stats = json.load(data_stats_open)
seq_length = data_stats['seq_length']
target_length = data_stats['target_length']
hic_diags =  data_stats['diagonal_offset']
target_crop = data_stats['crop_bp'] // data_stats['pool_width']
target_length1 = data_stats['seq_length'] // data_stats['pool_width']

# %% [markdown]
# ## Make predictions for saved tfrecords

# %%
### load data ###

# note: run %%bash get_data.sh 
# if you have not already downloaded the data

sequences = pd.read_csv(data_dir+'sequences.bed', sep='\t', names=['chr','start','stop','type'])
sequences_test = sequences.iloc[sequences['type'].values=='test']
sequences_test.reset_index(inplace=True, drop=True)

test_data = dataset.SeqDataset(data_dir, 'test', batch_size=8)


# test_targets is a float array with shape 
# [#regions, #pixels, target #target datasets]
# representing log(obs/exp)data, where #pixels 
# corresponds to the number of entries in the flattened
# upper-triangular representation of the matrix

# test_inputs are 1-hot encoded arrays with shape
# [#regions, 2^20 bp, 4 nucleotides datasets]

test_inputs, test_targets = test_data.numpy(return_inputs=True, return_outputs=True)
print('test_inputs shape:', test_inputs.shape)
# Out:
# test_inputs shape: (413, 1048576, 4)

# %%
### for converting from flattened upper-triangluar vector to symmetric matrix  ###

def from_upper_triu(vector_repr, matrix_len, num_diags):
    z = np.zeros((matrix_len,matrix_len))
    triu_tup = np.triu_indices(matrix_len,num_diags)
    z[triu_tup] = vector_repr
    for i in range(-num_diags+1,num_diags):
        set_diag(z, np.nan, i)
    return z + z.T

target_length1_cropped = target_length1 - 2*target_crop
print('flattened representation length:', target_length) 
print('symmetrix matrix size:', '('+str(target_length1_cropped)+','+str(target_length1_cropped)+')')
# Out:
# flattened representation length: 99681
# symmetrix matrix size: (448,448)

# %%
fig2_examples = [   'chr12:115163136-116211712',
                    'chr11:75429888-76478464',
                    'chr15:63281152-64329728' ]
fig2_inds = []
for seq in fig2_examples:
    print(seq)
    chrm,start,stop = seq.split(':')[0], seq.split(':')[1].split('-')[0], seq.split(':')[1].split('-')[1]
    test_ind = np.where( (sequences_test['chr'].values== chrm) *
                         (sequences_test['start'].values== int(start))*
                         (sequences_test['stop'].values==  int(stop ))  )[0][0]
    fig2_inds.append(test_ind)
fig2_inds
# Out:
# chr12:115163136-116211712
# chr11:75429888-76478464
# chr15:63281152-64329728
# [85, 402, 393]

# %%
### make predictions and plot the three examples above ###

target_index = 0 # HFF 

for test_index in fig2_inds:
    chrm, seq_start, seq_end = sequences_test.iloc[test_index][0:3]
    myseq_str = chrm+':'+str(seq_start)+'-'+str(seq_end)
    print(' ')
    print(myseq_str)
    
    test_target = test_targets[test_index:test_index+1,:,:]
    test_pred = seqnn_model.model.predict(test_inputs[test_index:test_index+1,:,:])

    plt.figure(figsize=(8,4))
    target_index = 0
    vmin=-2; vmax=2

    # plot pred
    plt.subplot(121) 
    mat = from_upper_triu(test_pred[:,:,target_index], target_length1_cropped, hic_diags)
    im = plt.matshow(mat, fignum=False, cmap= 'RdBu_r', vmax=vmax, vmin=vmin)
    plt.colorbar(im, fraction=.04, pad = 0.05, ticks=[-2,-1, 0, 1,2]);
    plt.title('pred-'+str(hic_num_to_name_dict[target_index]),y=1.15 )
    plt.ylabel(myseq_str)

    # plot target 
    plt.subplot(122) 
    mat = from_upper_triu(test_target[:,:,target_index], target_length1_cropped, hic_diags)
    im = plt.matshow(mat, fignum=False, cmap= 'RdBu_r', vmax=vmax, vmin=vmin)
    plt.colorbar(im, fraction=.04, pad = 0.05, ticks=[-2,-1, 0, 1,2]);
    plt.title( 'target-'+str(hic_num_to_name_dict[target_index]),y=1.15)

    plt.tight_layout()
    plt.show()
# Out:
#
# chr12:115163136-116211712
# 1/1 [==============================] - 0s 267ms/step
#
# chr11:75429888-76478464
# 1/1 [==============================] - 0s 257ms/step
#
# chr15:63281152-64329728
# 1/1 [==============================] - 0s 273ms/step

# %% [markdown]
# ## Make a prediction from sequence

# %%
### make a prediction from sequence ###

if not os.path.isfile('./data/hg38.ml.fa'):
    print('downloading hg38.ml.fa')
    subprocess.call('curl -o ./data/hg38.ml.fa.gz https://storage.googleapis.com/basenji_barnyard2/hg38.ml.fa.gz', shell=True)
    subprocess.call('gunzip ./data/hg38.ml.fa.gz', shell=True)

fasta_open = pysam.Fastafile('./data/hg38.ml.fa')

# %%
# this example uses the sequence for the test set region
# with the corresponding test_index, but
# predictions can be made for any DNA sequence of length = seq_length = 2^20

chrm, seq_start, seq_end = sequences_test.iloc[test_index][0:3] 
seq = fasta_open.fetch( chrm, seq_start, seq_end ).upper()
if len(seq) != seq_length: raise ValueError('len(seq) != seq_length')

# seq_1hot is a np.array with shape [2^20 bp, 4 nucleotides]
# representing 1-hot encoded DNA sequence
seq_1hot = dna_io.dna_1hot(seq)

# %%
# expand input dimensions, as model accepts arrays of size [#regions,2^20bp, 4]
test_pred_from_seq = seqnn_model.model.predict(np.expand_dims(seq_1hot,0))
# Out:
# This is triu_tup (array([  0,   0,   0, ..., 444, 444, 445]), array([  2,   3,   4, ..., 446, 447, 447]))
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe0dc775ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe0dc775ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step

# %%
# plot pred

plt.figure(figsize=(8,4))
target_index = 0
vmin=-2; vmax=2

#transform from flattened representation to symmetric matrix representation
mat = from_upper_triu(test_pred_from_seq[:,:,target_index], target_length1_cropped, hic_diags)

plt.subplot(121) 
im = plt.matshow(mat, fignum=False, cmap= 'RdBu_r', vmax=vmax, vmin=vmin)
plt.colorbar(im, fraction=.04, pad = 0.05, ticks=[-2,-1, 0, 1,2]);
plt.title('pred-'+str(hic_num_to_name_dict[target_index]),y=1.15 )
plt.ylabel(myseq_str)

# plot target 
plt.subplot(122) 
mat = from_upper_triu(test_target[:,:,target_index], target_length1_cropped, hic_diags)
im = plt.matshow(mat, fignum=False, cmap= 'RdBu_r', vmax=vmax, vmin=vmin)
plt.colorbar(im, fraction=.04, pad = 0.05, ticks=[-2,-1, 0, 1,2]);
plt.title( 'target-'+str(hic_num_to_name_dict[target_index]),y=1.15)

plt.tight_layout()
plt.show()
